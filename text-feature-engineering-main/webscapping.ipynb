# %% [markdown]
# ### Dataset Collection
#
# - Scrape product reviews from Flipkart or Amazon (minimum 100 reviews)
#
# - You can use Selenium, BeautifulSoup, or any reliable scraping method
#
# - Store data in CSV format with at least one column: review_text
#
# - Ensure data is clean and readable
#
# - Do not scrape restricted or sensitive content

# %%
import requests
from bs4 import BeautifulSoup as bs
# Out:
# /Users/rajugaru/Desktop/FullStack-AI/TestDummy/env/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
def scrape(url):
    headers = {
        'authority': 'www.amazon.com',
        'pragma': 'no-cache',
        'cache-control': 'no-cache',
        'dnt': '1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (X11; CrOS x86_64 8172.45.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.64 Safari/537.36',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'sec-fetch-site': 'none',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-dest': 'document',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
    }

    # Download the page using requests
    print("Downloading %s"%url)
    r = requests.get(url, headers=headers)

    
    # Simple check to check if page was blocked (Usually 503)
    if r.status_code > 500:
        if "To discuss automated access to Amazon data please contact" in r.text:
            print("Page %s was blocked by Amazon. Please try using better proxies\n"%url)
        else:
            print("Page %s must have been blocked by Amazon as the status code was %d"%(url,r.status_code))
        return None
    # Pass the HTML of the page and create
    return r.text

# %%
urls = ["https://www.amazon.com/s?k=tv"]
##        "https://www.amazon.in/s?k=mobile", 
##        "https://www.amazon.in/s?k=earbuds+buds", "https://www.amazon.in/s?k=earbuds+samsung"]

# %%
extracted_links = []
for url in urls:
  page = scrape(url)
  page_html = bs(page,"html.parser")
  per_product = page_html.find_all("div" ,{"class" :"rush-component"})
  a_tags = page_html.find_all("a", class_="a-link-normal")
  print(f"URL: {url} Count: {len(a_tags)}")
  if a_tags:
      for tag in a_tags:
          link = tag.get("href")
          if link:
              extracted_links.append(link)
# Out:
# Downloading https://www.amazon.com/s?k=tv
# URL: https://www.amazon.com/s?k=tv Count: 407

# %%
product_links = [a for a in extracted_links if a.find('#customerReviews') > 0 ]

# %%
len(product_links)
# Out:
# 19

# %%
reviews =[]
for url in product_links:
  try:
    full_url = url if url.startswith('https:') else 'https://www.amazon.in' + url
    page = scrape(full_url)
    soup = bs(page,"html.parser")
    div_reviews = soup.find_all('div', {'class': 'a-section celwidget'})
    for review_div in div_reviews:
      star_rating_span = review_div.find('i', {'data-hook': 'review-star-rating'})
      star_rating = star_rating_span.find('span', class_='a-icon-alt').get_text(strip=True) if star_rating_span else 'N/A'

      review_title_span = review_div.find('a', {'data-hook': 'review-title'})
      review_title = review_title_span.find_all('span')[-1].get_text(strip=True) if review_title_span and review_title_span.find_all('span') else 'N/A'

      review_body_span = review_div.find('span', {'data-hook': 'review-body'})
      review_description = review_body_span.get_text(strip=True) if review_body_span else 'N/A'
      if star_rating != 'N/A' and review_title != 'N/A' and review_description != 'N/A':
        reviews.append((star_rating,review_title, review_description))
  except Exception as e:
    print(f"Error processing URL: {url}")
# Out:
# Downloading https://www.amazon.in/INSIGNIA-50-inch-4K-UHD-Fire-TV/dp/B0F19KLHG3/ref=sr_1_1?dib=eyJ2IjoiMSJ9.95nCAQsqHUBJRumedVp6pbbyBV7_cG3i6lE7Gn1GMu95SbocAiFz40YKPDSn6G5VwCYZJtIIIN8cso3V71h2fUHvAx4FS4JRt_sthgLKPBM4_5My1pNYzQlRSR9Hx5EGIbdblMI2EEGAf3maTWq_m3JL7Mnos70RVgIbot9-u2RCYco8PrNlAH6xwDY6h-cXWetrBQh6LB-l8IE8KihvBoFa9KgXmnv3e-BcTvruQIo.ZXhV8iSoP8la6BOr19DK_HKT6mUhCSGdxtwo16G3jWM&dib_tag=se&keywords=tv&qid=1775919953&sr=8-1#customerReviews
# Downloading https://www.amazon.in/INSIGNIA-55-inch-4K-UHD-Fire-TV/dp/B0F1BXQNR5/ref=sr_1_2?dib=eyJ2IjoiMSJ9.95nCAQsqHUBJRumedVp6pbbyBV7_cG3i6lE7Gn1GMu95SbocAiFz40YKPDSn6G5VwCYZJtIIIN8cso3V71h2fUHvAx4FS4JRt_sthgLKPBM4_5My1pNYzQlRSR9Hx5EGIbdblMI2EEGAf3maTWq_m3JL7Mnos70RVgIbot9-u2RCYco8PrNlAH6xwDY6h-cXWetrBQh6LB-l8IE8KihvBoFa9KgXmnv3e-BcTvruQIo.ZXhV8iSoP8la6BOr19DK_HKT6mUhCSGdxtwo16G3jWM&dib_tag=se&keywords=tv&qid=1775919953&sr=8-2#customerReviews
# Downloading https://aax-us-east-retail-direct.amazon.com/x/c/JJWFSIGYtZ444Ttrr79AoRgAAAGdfRP1pgEAAAH2AQBvbm9fdHhuX2JpZDMgICBvbm9fdHhuX2ltcDIgICAyhW65/clv1c_ek-IBAfWbcbaXT1XZ_v_Sd5aolMAZ0aPZ8_Z6ptzPUNCIx6gwP-oFKdTP4m1dVj_bE2yG1h-inJKI81tRRR7-z-bZUuC7eqyJSCk_eclPBz6W4Cs6f7iDzi4I314492KwadB-M0THTSeE1008_B373Dbo8_sti36Uwbw2S7CpFa-7YsJ2hWGDXw1VM8fFw59vb3bJ4nLE5TN3NyVOeIq6OITlWWh5G_fhzKng6N5lL5wr2WYzdQphHOeRoxsNeymTaloPOXSanxGx--FjnGpDdaUUHTjZh_XyXeDm1BbIgC2Bksgm0vqWpayXequTWVh4FV1WS3kZwaH4s31KOsCWQR1izzu_6metZ907J3oKlROMhAcLJPp53zgZeMI0Pe9KkDIGfTpBMK-JvgCoa-pHr56_iTMsqa67KZDsAyw5w9htg0pDGkyXVU5TMHVEqGquTZLH6MVnmCnNHScTeVYBigXM-x3pyrwsZTu2J46iZSTca3FU_XaLPbArtLFLzGFufETm2aXp5jtwaMFiTq7qollpFcZTx6q0_Ozf10zcU53_4f07WnXhBWHpWwFazNffz8bv81UFko5JO5g7OxbnqaAq75fzB6C94JFAlr0JHLGTaUXngXy7kc3f-ICK0fbwTjG1VZtguQ00LGwDFpHhDJ4gIVKNnCIyNhKBXP9074R4FF2H6CKSOT-_cPpipQqnI1qPiOPBGsoONCLd0i36crneJRAh0c4lKPUzzgqE4o48Mq3A-aehytf9tJqwRqjZ4gJnHIREPMI3Ee_C4offYS7FLb5uTuingN31zH6cf_CsdGQS2SevqrhyRi5aIPoB9Enn8R_40Ip7Yb1McXq52piw5zIYnE0DU17uDWHiGrl9ASepOCtx1fTKh9hBfgnLjWfGCK2ueTVVFvvJkECiFZcXezJpaK7jixSmZqSWRnw2dx4uWIgxWRD5hmkDq1L68kXzraU7IZDfKQpel0FSuq3DR7wNrsS2Khl4ELcN2TvWrKBSDwcUcnUF5eXCsZRTdtjiM2__YmTFQ5Rh7jhFV-uLuMSMjQutzehatuMK_C--EZTWyfRndXnsUh2991sp-Yr4LyLYfaDuKI1pJN7OVeJXCUjoU2ydHe_WxPzATOsU1BiKLUfQJ9Rp8Z-Ni9tduErOouuN5BEOWrEDv-eMR31OcKBWO1UbpmvOzy0IL3IdvWrKu7y1mzIxz0OYZ5R4_JBOpThp8zW6EXMD6PCg-tJ5pR35ZmDNavS3Dv6NXxb46VvYAfP00qVwL33qvj7cpNH0jjXq4ShRYlcUBw0LrypRJGyFBC5L6FU76TGn6Rt68ddUzS6Nl2ewQBlX6rvGN__cpCyqnw8W9hkRZ7b8KbLvnDof88VpWJCmTA2epfaIObWpGeIGmLLSXmNIf2nSgzMKaheCX_MaxDnqSEldjZglYYQx1_eNHe9hdds0cGTA6hsC7SGXrCqxrC_hOn7Urs1WIK-aoXkWpAQpeP4YGLnkFJ4Sjc9tAxEIZRfbuI-1veIjkTmBms4egbKpmhH1-94B15O3zxf15sUNrWkXebx43mF8zvu5CZF549uEJgjmWRABcJA49rRhkZrVzlT1Q8sfRxD2O2QQqnXlVVckj34m_g8HY07UZsw22NyfuXrD8ZeKwW2d_lHK8bDyPC6hD9amWbjhIwYVh5TCqGnTsLduMUcvyvk9A/https://www.amazon.com/gp/aw/d/B0DYQM4BDB/?_encoding=UTF8&pd_rd_plhdr=t&aaxitk=3f895efff9e5a8c474d8f56878178893&hsa_cr_id=0&qid=1775919953&sr=1-1-f02f01d6-adaf-4bef-9a7c-29308eff9043&ref_=sbx__sbtcd2_asin_0_rating&pd_rd_w=Yt5VX&content-id=amzn1.sym.d3360101-5266-4e0e-8e4a-de7eb0be6ed9%3Aamzn1.sym.d3360101-5266-4e0e-8e4a-de7eb0be6ed9&pf_rd_p=d3360101-5266-4e0e-8e4a-de7eb0be6ed9&pf_rd_r=G87D9TSDF9SGC3CR19YR&pd_rd_wg=uO23o&pd_rd_r=c2d93a0e-fcde-496d-a7f2-cc5ae7963200#customerReviews
# Downloading https://aax-us-east-retail-direct.amazon.com/x/c/JJWFSIGYtZ444Ttrr79AoRgAAAGdfRP1pgEAAAH2AQBvbm9fdHhuX2JpZDMgICBvbm9fdHhuX2ltcDIgICAyhW65/clv1c_ek-IBAfWbcbaXT1XZ_v_Sd5aolMAZ0aPZ8_Z6ptzPUNCIx6gwP-oFKdTP4m1dVj_bE2yG1h-inJKI81tRRR7-z-bZUuC7eqyJSCk_eclPBz6W4Cs6f7iDzi4I314492KwadB-M0THTSeE1008_B373Dbo8_sti36Uwbw2S7CpFa-7YsJ2hWGDXw1VM8fFw59vb3bJ4nLE5TN3NyVOeIq6OITlWWh5G_fhzKng6N5lL5wr2WYzdQphHOeRoxsNeymTaloPOXSanxGx--FjnGpDdaUUHTjZh_XyXeDm1BbIgC2Bksgm0vqWpayXequTWVh4FV1WS3kZwaH4s31KOsCWQR1izzu_6metZ907J3oKlROMhAcLJPp53zgZeMI0Pe9KkDIGfTpBMK-JvgCoa-pHr56_iTMsqa67KZDsAyw5w9htg0pDGkyXVU5TMHVEqGquTZLH6MVnmCnNHScTeVYBigXM-x3pyrwsZTu2J46iZSTca3FU_XaLPbArtLFLzGFufETm2aXp5jtwaMFiTq7qollpFcZTx6q0_Ozf10zcU53_4f07WnXhBWHpWwFazNffz8bv81UFko5JO5g7OxbnqaAq75fzB6C94JFAlr0JHLGTaUXngXy7kc3f-ICK0fbwTjG1VZtguQ00LGwDFpHhDJ4gIVKNnCIyNhKBXP9074R4FF2H6CKSOT-_cPpipQqnI1qPiOPBGsoONCLd0i36crneJRAh0c4lKPUzzgqE4o48Mq3A-aehytf9tJqwRqjZ4gJnHIREPMI3Ee_C4offYS7FLb5uTuingN31zH6cf_CsdGQS2SevqrhyRi5aIPoB9Enn8R_40Ip7Yb1McXq52piw5zIYnE0DU17uDWHiGrl9ASepOCtx1fTKh9hBfgnLjWfGCK2ueTVVFvvJkECiFZcXezJpaK7jixSmZqSWRnw2dx4uWIgxWRD5hmkDq1L68kXzraU7IZDfKQpel0FSuq3DR7wNrsS2Khl4ELcN2TvWrKBSDwcUcnUF5eXCsZRTdtjiM2__YmTFQ5Rh7jhFV-uLuMSMjQutzehatuMK_C--EZTWyfRndXnsUh2991sp-Yr4LyLYfaDuKI1pJN7OVeJXCUjoU2ydHe_WxPzATOsU1BiKLUfQJ9Rp8Z-Ni9tduErOouuN5BEOWrEDv-eMR31OcKBWO1UbpmvOzy0IL3IdvWrKu7y1mzIxz0OYZ5R4_JBOpThp8zW6EXMD6PCg-tJ5pR35ZmDNavS3Dv6NXxb46VvYAfP00qVwL33qvj7cpNH0jjXq4ShRYlcUBw0LrypRJGyFBC5L6FU76TGn6Rt68ddUzS6Nl2ewQBlX6rvGN__cpCyqnw8W9hkRZ7b8KbLvnDof88VpWJCmTA2epfaIObWpGeIGmLLSXmNIf2nSgzMKaheCX_MaxDnqSEldjZglYYQx1_eNHe9hdds0cGTA6hsC7SGXrCqxrC_hOn7Urs1WIK-aoXkWpAQpeP4YGLnkFJ4Sjc9tAxEIZRfbuI-1veIjkTmBms4egbKpmhH1-94B15O3zxf15sUNrWkXebx43mF8zvu5CZF549uEJgjmWRABcJA49rRhkZrVzlT1Q8sfRxD2O2QQqnXlVVckj34m_g8HY07UZsw22NyfuXrD8ZeKwW2d_lHK8bDyPC6hD9amWbjhIwYVh5TCqGnTsLduMUcvyvk9A/https://www.amazon.com/gp/aw/d/B0DYQMWSKG/?_encoding=UTF8&pd_rd_plhdr=t&aaxitk=3f895efff9e5a8c474d8f56878178893&hsa_cr_id=0&qid=1775919953&sr=1-2-f02f01d6-adaf-4bef-9a7c-29308eff9043&ref_=sbx__sbtcd2_asin_1_rating&pd_rd_w=Yt5VX&content-id=amzn1.sym.d3360101-5266-4e0e-8e4a-de7eb0be6ed9%3Aamzn1.sym.d3360101-5266-4e0e-8e4a-de7eb0be6ed9&pf_rd_p=d3360101-5266-4e0e-8e4a-de7eb0be6ed9&pf_rd_r=G87D9TSDF9SGC3CR19YR&pd_rd_wg=uO23o&pd_rd_r=c2d93a0e-fcde-496d-a7f2-cc5ae7963200#customerReviews
# Downloading https://aax-us-east-retail-direct.amazon.com/x/c/JJWFSIGYtZ444Ttrr79AoRgAAAGdfRP1pgEAAAH2AQBvbm9fdHhuX2JpZDMgICBvbm9fdHhuX2ltcDIgICAyhW65/clv1c_ek-IBAfWbcbaXT1XZ_v_Sd5aolMAZ0aPZ8_Z6ptzPUNCIx6gwP-oFKdTP4m1dVj_bE2yG1h-inJKI81tRRR7-z-bZUuC7eqyJSCk_eclPBz6W4Cs6f7iDzi4I314492KwadB-M0THTSeE1008_B373Dbo8_sti36Uwbw2S7CpFa-7YsJ2hWGDXw1VM8fFw59vb3bJ4nLE5TN3NyVOeIq6OITlWWh5G_fhzKng6N5lL5wr2WYzdQphHOeRoxsNeymTaloPOXSanxGx--FjnGpDdaUUHTjZh_XyXeDm1BbIgC2Bksgm0vqWpayXequTWVh4FV1WS3kZwaH4s31KOsCWQR1izzu_6metZ907J3oKlROMhAcLJPp53zgZeMI0Pe9KkDIGfTpBMK-JvgCoa-pHr56_iTMsqa67KZDsAyw5w9htg0pDGkyXVU5TMHVEqGquTZLH6MVnmCnNHScTeVYBigXM-x3pyrwsZTu2J46iZSTca3FU_XaLPbArtLFLzGFufETm2aXp5jtwaMFiTq7qollpFcZTx6q0_Ozf10zcU53_4f07WnXhBWHpWwFazNffz8bv81UFko5JO5g7OxbnqaAq75fzB6C94JFAlr0JHLGTaUXngXy7kc3f-ICK0fbwTjG1VZtguQ00LGwDFpHhDJ4gIVKNnCIyNhKBXP9074R4FF2H6CKSOT-_cPpipQqnI1qPiOPBGsoONCLd0i36crneJRAh0c4lKPUzzgqE4o48Mq3A-aehytf9tJqwRqjZ4gJnHIREPMI3Ee_C4offYS7FLb5uTuingN31zH6cf_CsdGQS2SevqrhyRi5aIPoB9Enn8R_40Ip7Yb1McXq52piw5zIYnE0DU17uDWHiGrl9ASepOCtx1fTKh9hBfgnLjWfGCK2ueTVVFvvJkECiFZcXezJpaK7jixSmZqSWRnw2dx4uWIgxWRD5hmkDq1L68kXzraU7IZDfKQpel0FSuq3DR7wNrsS2Khl4ELcN2TvWrKBSDwcUcnUF5eXCsZRTdtjiM2__YmTFQ5Rh7jhFV-uLuMSMjQutzehatuMK_C--EZTWyfRndXnsUh2991sp-Yr4LyLYfaDuKI1pJN7OVeJXCUjoU2ydHe_WxPzATOsU1BiKLUfQJ9Rp8Z-Ni9tduErOouuN5BEOWrEDv-eMR31OcKBWO1UbpmvOzy0IL3IdvWrKu7y1mzIxz0OYZ5R4_JBOpThp8zW6EXMD6PCg-tJ5pR35ZmDNavS3Dv6NXxb46VvYAfP00qVwL33qvj7cpNH0jjXq4ShRYlcUBw0LrypRJGyFBC5L6FU76TGn6Rt68ddUzS6Nl2ewQBlX6rvGN__cpCyqnw8W9hkRZ7b8KbLvnDof88VpWJCmTA2epfaIObWpGeIGmLLSXmNIf2nSgzMKaheCX_MaxDnqSEldjZglYYQx1_eNHe9hdds0cGTA6hsC7SGXrCqxrC_hOn7Urs1WIK-aoXkWpAQpeP4YGLnkFJ4Sjc9tAxEIZRfbuI-1veIjkTmBms4egbKpmhH1-94B15O3zxf15sUNrWkXebx43mF8zvu5CZF549uEJgjmWRABcJA49rRhkZrVzlT1Q8sfRxD2O2QQqnXlVVckj34m_g8HY07UZsw22NyfuXrD8ZeKwW2d_lHK8bDyPC6hD9amWbjhIwYVh5TCqGnTsLduMUcvyvk9A/https://www.amazon.com/gp/aw/d/B0DYQGRHX3/?_encoding=UTF8&pd_rd_plhdr=t&aaxitk=3f895efff9e5a8c474d8f56878178893&hsa_cr_id=0&qid=1775919953&sr=1-3-f02f01d6-adaf-4bef-9a7c-29308eff9043&ref_=sbx__sbtcd2_asin_2_rating&pd_rd_w=Yt5VX&content-id=amzn1.sym.d3360101-5266-4e0e-8e4a-de7eb0be6ed9%3Aamzn1.sym.d3360101-5266-4e0e-8e4a-de7eb0be6ed9&pf_rd_p=d3360101-5266-4e0e-8e4a-de7eb0be6ed9&pf_rd_r=G87D9TSDF9SGC3CR19YR&pd_rd_wg=uO23o&pd_rd_r=c2d93a0e-fcde-496d-a7f2-cc5ae7963200#customerReviews
# Downloading https://www.amazon.in/Roku-Smart-2026-Television-Streaming/dp/B0FV57TPWT/ref=sr_1_3?dib=eyJ2IjoiMSJ9.95nCAQsqHUBJRumedVp6pbbyBV7_cG3i6lE7Gn1GMu95SbocAiFz40YKPDSn6G5VwCYZJtIIIN8cso3V71h2fUHvAx4FS4JRt_sthgLKPBM4_5My1pNYzQlRSR9Hx5EGIbdblMI2EEGAf3maTWq_m3JL7Mnos70RVgIbot9-u2RCYco8PrNlAH6xwDY6h-cXWetrBQh6LB-l8IE8KihvBoFa9KgXmnv3e-BcTvruQIo.ZXhV8iSoP8la6BOr19DK_HKT6mUhCSGdxtwo16G3jWM&dib_tag=se&keywords=tv&qid=1775919953&sr=8-3#customerReviews
# Downloading https://www.amazon.in/Toshiba-40-inch-LED-Full-HD-Fire-TV/dp/B0F256YJCK/ref=sr_1_4?dib=eyJ2IjoiMSJ9.95nCAQsqHUBJRumedVp6pbbyBV7_cG3i6lE7Gn1GMu95SbocAiFz40YKPDSn6G5VwCYZJtIIIN8cso3V71h2fUHvAx4FS4JRt_sthgLKPBM4_5My1pNYzQlRSR9Hx5EGIbdblMI2EEGAf3maTWq_m3JL7Mnos70RVgIbot9-u2RCYco8PrNlAH6xwDY6h-cXWetrBQh6LB-l8IE8KihvBoFa9KgXmnv3e-BcTvruQIo.ZXhV8iSoP8la6BOr19DK_HKT6mUhCSGdxtwo16G3jWM&dib_tag=se&keywords=tv&qid=1775919953&sr=8-4#customerReviews
# Downloading https://www.amazon.in/INSIGNIA-32-inch-LED-HD-Fire-TV/dp/B0F7RZ1MS9/ref=sr_1_5?dib=eyJ2IjoiMSJ9.95nCAQsqHUBJRumedVp6pbbyBV7_cG3i6lE7Gn1GMu95SbocAiFz40YKPDSn6G5VwCYZJtIIIN8cso3V71h2fUHvAx4FS4JRt_sthgLKPBM4_5My1pNYzQlRSR9Hx5EGIbdblMI2EEGAf3maTWq_m3JL7Mnos70RVgIbot9-u2RCYco8PrNlAH6xwDY6h-cXWetrBQh6LB-l8IE8KihvBoFa9KgXmnv3e-BcTvruQIo.ZXhV8iSoP8la6BOr19DK_HKT6mUhCSGdxtwo16G3jWM&dib_tag=se&keywords=tv&qid=1775919953&sr=8-5#customerReviews
# Downloading https://www.amazon.in/Roku-Smart-2025-Television-Entertainment/dp/B0F8XV7MPP/ref=sr_1_6?dib=eyJ2IjoiMSJ9.95nCAQsqHUBJRumedVp6pbbyBV7_cG3i6lE7Gn1GMu95SbocAiFz40YKPDSn6G5VwCYZJtIIIN8cso3V71h2fUHvAx4FS4JRt_sthgLKPBM4_5My1pNYzQlRSR9Hx5EGIbdblMI2EEGAf3maTWq_m3JL7Mnos70RVgIbot9-u2RCYco8PrNlAH6xwDY6h-cXWetrBQh6LB-l8IE8KihvBoFa9KgXmnv3e-BcTvruQIo.ZXhV8iSoP8la6BOr19DK_HKT6mUhCSGdxtwo16G3jWM&dib_tag=se&keywords=tv&qid=1775919953&sr=8-6#customerReviews
# Downloading https://www.amazon.in/Samsung-Processor-MetalStream-Security-Compatible/dp/B0DXMW74JZ/ref=sr_1_7?dib=eyJ2IjoiMSJ9.95nCAQsqHUBJRumedVp6pbbyBV7_cG3i6lE7Gn1GMu95SbocAiFz40YKPDSn6G5VwCYZJtIIIN8cso3V71h2fUHvAx4FS4JRt_sthgLKPBM4_5My1pNYzQlRSR9Hx5EGIbdblMI2EEGAf3maTWq_m3JL7Mnos70RVgIbot9-u2RCYco8PrNlAH6xwDY6h-cXWetrBQh6LB-l8IE8KihvBoFa9KgXmnv3e-BcTvruQIo.ZXhV8iSoP8la6BOr19DK_HKT6mUhCSGdxtwo16G3jWM&dib_tag=se&keywords=tv&qid=1775919953&sr=8-7#customerReviews
# Downloading https://www.amazon.in/Fire-TV-4-Series-55-inch/dp/B0DFNTKTYN/ref=sr_1_8?dib=eyJ2IjoiMSJ9.95nCAQsqHUBJRumedVp6pbbyBV7_cG3i6lE7Gn1GMu95SbocAiFz40YKPDSn6G5VwCYZJtIIIN8cso3V71h2fUHvAx4FS4JRt_sthgLKPBM4_5My1pNYzQlRSR9Hx5EGIbdblMI2EEGAf3maTWq_m3JL7Mnos70RVgIbot9-u2RCYco8PrNlAH6xwDY6h-cXWetrBQh6LB-l8IE8KihvBoFa9KgXmnv3e-BcTvruQIo.ZXhV8iSoP8la6BOr19DK_HKT6mUhCSGdxtwo16G3jWM&dib_tag=se&keywords=tv&qid=1775919953&sr=8-8#customerReviews
# Downloading https://www.amazon.in/Roku-Smart-2025-Television-Entertainment/dp/B0DWHKF7V5/ref=sr_1_9?dib=eyJ2IjoiMSJ9.95nCAQsqHUBJRumedVp6pbbyBV7_cG3i6lE7Gn1GMu95SbocAiFz40YKPDSn6G5VwCYZJtIIIN8cso3V71h2fUHvAx4FS4JRt_sthgLKPBM4_5My1pNYzQlRSR9Hx5EGIbdblMI2EEGAf3maTWq_m3JL7Mnos70RVgIbot9-u2RCYco8PrNlAH6xwDY6h-cXWetrBQh6LB-l8IE8KihvBoFa9KgXmnv3e-BcTvruQIo.ZXhV8iSoP8la6BOr19DK_HKT6mUhCSGdxtwo16G3jWM&dib_tag=se&keywords=tv&qid=1775919953&sr=8-9#customerReviews
# Downloading https://www.amazon.in/Hisense-40-Inch-Class-Compatibility-40A4NR/dp/B0D5KKV2MS/ref=sr_1_10?dib=eyJ2IjoiMSJ9.95nCAQsqHUBJRumedVp6pbbyBV7_cG3i6lE7Gn1GMu95SbocAiFz40YKPDSn6G5VwCYZJtIIIN8cso3V71h2fUHvAx4FS4JRt_sthgLKPBM4_5My1pNYzQlRSR9Hx5EGIbdblMI2EEGAf3maTWq_m3JL7Mnos70RVgIbot9-u2RCYco8PrNlAH6xwDY6h-cXWetrBQh6LB-l8IE8KihvBoFa9KgXmnv3e-BcTvruQIo.ZXhV8iSoP8la6BOr19DK_HKT6mUhCSGdxtwo16G3jWM&dib_tag=se&keywords=tv&qid=1775919953&sr=8-10#customerReviews
# Downloading https://www.amazon.in/Toshiba-50-inch-4K-LED-Fire-TV/dp/B0DZ8R71DB/ref=sr_1_11?dib=eyJ2IjoiMSJ9.95nCAQsqHUBJRumedVp6pbbyBV7_cG3i6lE7Gn1GMu95SbocAiFz40YKPDSn6G5VwCYZJtIIIN8cso3V71h2fUHvAx4FS4JRt_sthgLKPBM4_5My1pNYzQlRSR9Hx5EGIbdblMI2EEGAf3maTWq_m3JL7Mnos70RVgIbot9-u2RCYco8PrNlAH6xwDY6h-cXWetrBQh6LB-l8IE8KihvBoFa9KgXmnv3e-BcTvruQIo.ZXhV8iSoP8la6BOr19DK_HKT6mUhCSGdxtwo16G3jWM&dib_tag=se&keywords=tv&qid=1775919953&sr=8-11#customerReviews
# Downloading https://www.amazon.in/Samsung-65-Inch-Tracking-Processor-upscaling/dp/B0DXMT6CJP/ref=sr_1_12?dib=eyJ2IjoiMSJ9.95nCAQsqHUBJRumedVp6pbbyBV7_cG3i6lE7Gn1GMu95SbocAiFz40YKPDSn6G5VwCYZJtIIIN8cso3V71h2fUHvAx4FS4JRt_sthgLKPBM4_5My1pNYzQlRSR9Hx5EGIbdblMI2EEGAf3maTWq_m3JL7Mnos70RVgIbot9-u2RCYco8PrNlAH6xwDY6h-cXWetrBQh6LB-l8IE8KihvBoFa9KgXmnv3e-BcTvruQIo.ZXhV8iSoP8la6BOr19DK_HKT6mUhCSGdxtwo16G3jWM&dib_tag=se&keywords=tv&qid=1775919953&sr=8-12#customerReviews
# Downloading https://www.amazon.in/Hisense-32-Inch-Class-1080p-32A4NF/dp/B0DYQZFXSN/ref=sr_1_13?dib=eyJ2IjoiMSJ9.95nCAQsqHUBJRumedVp6pbbyBV7_cG3i6lE7Gn1GMu95SbocAiFz40YKPDSn6G5VwCYZJtIIIN8cso3V71h2fUHvAx4FS4JRt_sthgLKPBM4_5My1pNYzQlRSR9Hx5EGIbdblMI2EEGAf3maTWq_m3JL7Mnos70RVgIbot9-u2RCYco8PrNlAH6xwDY6h-cXWetrBQh6LB-l8IE8KihvBoFa9KgXmnv3e-BcTvruQIo.ZXhV8iSoP8la6BOr19DK_HKT6mUhCSGdxtwo16G3jWM&dib_tag=se&keywords=tv&qid=1775919953&sr=8-13#customerReviews
# Downloading https://www.amazon.in/Samsung-55-Inch-Tracking-Processor-upscaling/dp/B0DXMY6KV8/ref=sr_1_14?dib=eyJ2IjoiMSJ9.95nCAQsqHUBJRumedVp6pbbyBV7_cG3i6lE7Gn1GMu95SbocAiFz40YKPDSn6G5VwCYZJtIIIN8cso3V71h2fUHvAx4FS4JRt_sthgLKPBM4_5My1pNYzQlRSR9Hx5EGIbdblMI2EEGAf3maTWq_m3JL7Mnos70RVgIbot9-u2RCYco8PrNlAH6xwDY6h-cXWetrBQh6LB-l8IE8KihvBoFa9KgXmnv3e-BcTvruQIo.ZXhV8iSoP8la6BOr19DK_HKT6mUhCSGdxtwo16G3jWM&dib_tag=se&keywords=tv&qid=1775919953&sr=8-14#customerReviews
# Downloading https://www.amazon.in/Hisense-40-Inch-Class-1080p-40A4NF/dp/B0DYR3D7QQ/ref=sr_1_15?dib=eyJ2IjoiMSJ9.95nCAQsqHUBJRumedVp6pbbyBV7_cG3i6lE7Gn1GMu95SbocAiFz40YKPDSn6G5VwCYZJtIIIN8cso3V71h2fUHvAx4FS4JRt_sthgLKPBM4_5My1pNYzQlRSR9Hx5EGIbdblMI2EEGAf3maTWq_m3JL7Mnos70RVgIbot9-u2RCYco8PrNlAH6xwDY6h-cXWetrBQh6LB-l8IE8KihvBoFa9KgXmnv3e-BcTvruQIo.ZXhV8iSoP8la6BOr19DK_HKT6mUhCSGdxtwo16G3jWM&dib_tag=se&keywords=tv&qid=1775919953&sr=8-15#customerReviews
# Downloading https://www.amazon.in/SAMSUNG-32-Inch-Object-Tracking-Security/dp/B0DXN3T1GD/ref=sr_1_16?dib=eyJ2IjoiMSJ9.95nCAQsqHUBJRumedVp6pbbyBV7_cG3i6lE7Gn1GMu95SbocAiFz40YKPDSn6G5VwCYZJtIIIN8cso3V71h2fUHvAx4FS4JRt_sthgLKPBM4_5My1pNYzQlRSR9Hx5EGIbdblMI2EEGAf3maTWq_m3JL7Mnos70RVgIbot9-u2RCYco8PrNlAH6xwDY6h-cXWetrBQh6LB-l8IE8KihvBoFa9KgXmnv3e-BcTvruQIo.ZXhV8iSoP8la6BOr19DK_HKT6mUhCSGdxtwo16G3jWM&dib_tag=se&keywords=tv&qid=1775919953&sr=8-16#customerReviews

# %%
import csv
import os

output_filename = 'data\\amazon_reviews.csv'

with open(output_filename, 'w', newline='', encoding='utf-8') as csvfile:
    csv_writer = csv.writer(csvfile)
    # Write the header row
    csv_writer.writerow(['Star Rating', 'Review Title', 'Review Description'])
    # Write the review data
    csv_writer.writerows(reviews)

print(f"Successfully saved {len(reviews)} reviews to {output_filename}")
# Out:
# Successfully saved 20 reviews to data\amazon_reviews.csv
